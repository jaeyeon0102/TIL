# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. 데이터 로드
file_path = '../data/seoul_subway_data.csv'  # 파일 경로는 실제 파일 위치에 맞게 수정하세요.
data = pd.read_csv(file_path)

# %%
data.columns
# Out:
# Index(['Date', 'DayOfWeek', 'Time', 'PassengerCount'], dtype='object')

# %%
data.head(5)
# Out:
#          Date DayOfWeek   Time  PassengerCount
# 0  2023-09-01    Friday  08:00            1200
# 1  2023-09-01    Friday  09:00             900
# 2  2023-09-01    Friday  10:00             500
# 3  2023-09-02  Saturday  08:00             300
# 4  2023-09-02  Saturday  09:00             200

# %%
# 2. 요일별 및이용객 수 집계
weekday_agg = data['DayOfWeek'].value_counts()
print(weekday_agg)
# Out:
# DayOfWeek
# Friday       3
# Saturday     3
# Sunday       3
# Monday       3
# Tuesday      3
# Wednesday    3
# Thursday     3
# Name: count, dtype: int64

# %%
# 2. 시간대별 이용객 수 집계
time_agg = data['Time'].value_counts()
print(time_agg)
# Out:
# Time
# 08:00    7
# 09:00    7
# 10:00    7
# Name: count, dtype: int64

# %%
# 3. 요일별 이용객 수 가로 막대 그래프 시각화
plt.figure(figsize=(10, 6))
weekday_agg.___________.plot(kind='barh', color='skyblue')
plt.title('Total Passengers by Day of the Week')
plt.xlabel('Passenger Count')
plt.ylabel('Day of the Week')
plt.show()

# %%
# 4. 시간대별 이용객 수 꺾은선 그래프 시각화
plt.figure(figsize=(10, 6))
time_agg.plot(kind='line', color='blue', marker='o')
plt.title('Total Passengers by Time of Day')
plt.xlabel('Time')
plt.ylabel('Passenger Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
